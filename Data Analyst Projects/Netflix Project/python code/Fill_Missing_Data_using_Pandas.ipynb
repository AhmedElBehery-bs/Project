# %% [markdown]
# ## Hybrid Enrichment

# %% [markdown]
# these two codes fills both the director and imdb_rating columns USING IMDb Static Datasets and API  , only when they are currently empty or missing.

# %% [markdown]
# #### Phase 1: IMDb Static Datasets (Bulk Fill)
#
# Data Fill source: https://datasets.imdbws.com/?spm=a2ty_o01.29997173.0.0.5e88c921oLLsPK
# How to Use:
# 1. Download the 3 IMDb files From the link:
#     - title.basics.tsv.gz
#     - title.crew.tsv.gz
#     - name.basics.tsv.gz
# 2. Extract them into a folder called imdb_datasets (or update IMDB_DIR).
# 3. Run the script — it will match by title + year and fill the "director" and "imdb_rating" columns.
# 4. after That Run the code Second Code, to fill the rest of the missing value using API

# %%
import pandas as pd
import os

# === CONFIG ===
INPUT_FILE = "netflix_titles.csv"
OUTPUT_FILE = "netflix_titles(modified using Dataset).csv"
IMDB_DIR = r"D:\Python\imdb_datasets"  # Folder with extracted .tsv files

# Check IMDb data folder
if not os.path.exists(IMDB_DIR):
    raise FileNotFoundError(
        f"Please download and extract IMDb .tsv files into: {IMDB_DIR}\n"
        "Required: title.basics.tsv, title.ratings.tsv, title.crew.tsv, name.basics.tsv"
    )

# === LOAD NETFLIX DATA ===
print("Loading Netflix dataset...")
df = pd.read_csv(INPUT_FILE)

# Add enrichment columns if missing
if 'imdb_rating' not in df.columns:
    df['imdb_rating'] = None
    print("✅ Added missing column: 'imdb_rating'")
if 'director' not in df.columns:
    df['director'] = None
    print("✅ Added missing column: 'director'")

# Record null counts (now safe to access)
orig_director_nulls = df['director'].isna().sum()
orig_rating_nulls = df['imdb_rating'].isna().sum()
orig_cast_nulls = df['cast'].isna().sum() if 'cast' in df.columns else 0
orig_country_nulls = df['country'].isna().sum() if 'country' in df.columns else 0

print(f"\nOriginal missing values:")
print(f"  director:     {orig_director_nulls}")
print(f"  imdb_rating:  {orig_rating_nulls}")
print(f"  cast:         {orig_cast_nulls}")
print(f"  country:      {orig_country_nulls}")

# Prepare matching keys
df = df.copy()
df['match_title'] = df['title'].astype(str).str.strip().str.lower()
df['match_year'] = pd.to_numeric(df['release_year'], errors='coerce')

# === LOAD IMDb title.basics ===
print("\nLoading title.basics.tsv...")
basics = pd.read_csv(
    os.path.join(IMDB_DIR, "title.basics.tsv"),
    sep='\t',
    usecols=['tconst', 'primaryTitle', 'startYear'],
    na_values='\\N',
    keep_default_na=False,
    dtype={'startYear': 'str'}
)

basics['imdb_title'] = basics['primaryTitle'].str.lower()
basics['imdb_year'] = pd.to_numeric(basics['startYear'], errors='coerce')

# === MATCH NETFLIX → IMDb (left join) ===
print("Matching titles...")
merged = pd.merge(
    df,
    basics[['tconst', 'imdb_title', 'imdb_year']],
    left_on=['match_title', 'match_year'],
    right_on=['imdb_title', 'imdb_year'],
    how='left'
)

# === LOAD RATINGS ===
print("Loading title.ratings.tsv...")
ratings = pd.read_csv(
    os.path.join(IMDB_DIR, "title.ratings.tsv"),
    sep='\t',
    na_values='\\N',
    keep_default_na=False
)
merged = pd.merge(merged, ratings[['tconst', 'averageRating']], on='tconst', how='left')

# === LOAD DIRECTORS ===
print("Loading title.crew.tsv and name.basics.tsv...")
crew = pd.read_csv(
    os.path.join(IMDB_DIR, "title.crew.tsv"),
    sep='\t',
    na_values='\\N',
    keep_default_na=False
)
names = pd.read_csv(
    os.path.join(IMDB_DIR, "name.basics.tsv"),
    sep='\t',
    usecols=['nconst', 'primaryName'],
    na_values='\\N',
    keep_default_na=False
)

name_dict = dict(zip(names['nconst'], names['primaryName']))

def directors_to_names(director_ids):
    if pd.isna(director_ids) or director_ids == '':
        return None
    ids = str(director_ids).split(',')
    name_list = [name_dict.get(id.strip()) for id in ids if id.strip() in name_dict]
    return ', '.join([n for n in name_list if n]) if name_list else None

merged = pd.merge(merged, crew[['tconst', 'directors']], on='tconst', how='left')
merged['imdb_director'] = merged['directors'].apply(directors_to_names)

# === SAFELY FILL ONLY MISSING VALUES ===
print("\nFilling missing imdb_rating and director...")

# Fill imdb_rating (all are initially None, so fill where IMDb has data)
rating_mask = merged['averageRating'].notna()
df.loc[rating_mask, 'imdb_rating'] = merged.loc[rating_mask, 'averageRating']

# Fill director (only where currently null/empty)
director_mask = (
    (df['director'].isna() | (df['director'] == '')) &
    merged['imdb_director'].notna()
)
df.loc[director_mask, 'director'] = merged.loc[director_mask, 'imdb_director']

# === REPORT & SAVE ===
new_director_nulls = df['director'].isna().sum()
new_rating_nulls = df['imdb_rating'].isna().sum()
new_cast_nulls = df['cast'].isna().sum() if 'cast' in df.columns else 0
new_country_nulls = df['country'].isna().sum() if 'country' in df.columns else 0

print(f"\nAfter enrichment:")
print(f"  director:     {orig_director_nulls} → {new_director_nulls}")
print(f"  imdb_rating:  {orig_rating_nulls} → {new_rating_nulls}")
print(f"  cast:         {orig_cast_nulls} → {new_cast_nulls} (unchanged)")
print(f"  country:      {orig_country_nulls} → {new_country_nulls} (unchanged)")

df.to_csv(OUTPUT_FILE, index=False)
print(f"\n✅ Saved to: {OUTPUT_FILE}")
# Out:
# Loading Netflix dataset...
# ✅ Added missing column: 'imdb_rating'
#
# Original missing values:
#   director:     2634
#   imdb_rating:  8807
#   cast:         825
#   country:      831
#
# Loading title.basics.tsv...
# Matching titles...
# Loading title.ratings.tsv...
# Loading title.crew.tsv and name.basics.tsv...
#
# Filling missing imdb_rating and director...
#
# After enrichment:
#   director:     2634 → 770
#   imdb_rating:  8807 → 3932
#   cast:         825 → 825 (unchanged)
#   country:      831 → 831 (unchanged)
#
# ✅ Saved to: netflix_titles(modified).csv

# %% [markdown]
# #### Phase 2: OMDb API (Gap Filling)
#
#
# ✅ Specifically:
#
# - If a row already has a value in imdb_rating (e.g., 8.5) OR director (e.g., "Jane Campion"), the code leaves it untouched.
# - If either field is missing (i.e., None, NaN, or an empty string ""), the code:
#  - Makes one API call to OMDb using the title (and optionally year).
#  - Fills in the missing field(s) from the API response:
#     - imdb_rating ← from OMDb’s imdbRating (converted to a number if possible).
#     - director ← from OMDb’s Director field (unless it’s "N/A").
# - Stoping when The API OMDb daily request limit reached
# ---
# ##### 🔑 How to Get a Free OMDb API Key (for enrichment script)
#
# 1. **Go to**: [https://www.omdbapi.com/apikey.aspx](https://www.omdbapi.com/apikey.aspx)
# 2. **Enter your email address** in the box.
# 3. **Click “Sign Up”**.
# 4. **Check your email inbox** — you’ll receive a message from OMDb with your **API key** (looks like: `abcd1234`).
# 5. **Copy the key** and paste it into the script where it says:
#    ```python
#    API_KEY = "your_key_here"
#    ```
#
# > ✅ That’s it! **No credit card**, no approval needed.
# > ⚠️ Free tier allows **1,000 requests per day** — enough for most small projects.
#
# API Important Notes From The Website:
# - Rate Limit: ~1,000 requests/day (free).
# - No bulk requests: You must query one title at a time.
# - Not real-time: Data is updated periodically, not instantly.
# - Commercial use? Requires a paid plan (not covered here).

# %%
import pandas as pd
import requests
import time
import os
import sys

# === CONFIG ===
API_KEY = "[insert your created API Key Here]"      # see "How to Get a Free OMDb API Key" above to know how to create it
INPUT_FILE = "netflix_titles(modified using Dataset).csv"
OUTPUT_FILE = "netflix_titles(modified_Final).csv"
SAVE_EVERY = 10  

# === LOAD DATA ===
if os.path.exists(OUTPUT_FILE):
    print(f"📁 Resuming from existing {OUTPUT_FILE}")
    df = pd.read_csv(OUTPUT_FILE)
else:
    df = pd.read_csv(INPUT_FILE)
    if 'imdb_rating' not in df.columns:
        df['imdb_rating'] = None
    if 'director' not in df.columns:
        df['director'] = None

if 'title' not in df.columns:
    raise ValueError("Your CSV must have a 'title' column!")

# Track how many rows we've processed in this run (for saving)
processed_count = 0

# FETCH RATINGS AND DIRECTORS 
for idx, row in df.iterrows():
    title = str(row['title']).strip()
    year = row.get('release_year', '')
    if pd.notna(year):
        try:
            year = str(int(float(year)))
        except (ValueError, TypeError):
            year = ''
    else:
        year = ''

    # Check current state
    current_rating = row.get('imdb_rating', None)
    current_director = row.get('director', '')

    rating_done = pd.notna(current_rating) and current_rating != ''
    director_done = not (pd.isna(current_director) or str(current_director).strip() == '')

    if rating_done and director_done:
        print(f"⏭️  Skipping (rating & director already present): {title}")
        processed_count += 1
    else:
        url = f"http://www.omdbapi.com/?t={requests.utils.quote(title)}&y={year}&apikey={API_KEY}"

        try:
            response = requests.get(url, timeout=10)
            data = response.json()
        except Exception as e:
            print(f"⚠️  Network error for '{title}' ({year}): {e}")
            time.sleep(1)
            processed_count += 1
            if processed_count % SAVE_EVERY == 0:
                df.to_csv(OUTPUT_FILE, index=False)
                print(f"💾 Saved progress at row {idx + 1} (every {SAVE_EVERY})")
            continue

        # Handle successful response
        if data.get('Response') == 'True':
            # --- Update IMDb Rating (if missing) ---
            if not rating_done:
                rating = data.get('imdbRating', 'N/A')
                if rating != 'N/A':
                    try:
                        df.at[idx, 'imdb_rating'] = float(rating)
                    except ValueError:
                        df.at[idx, 'imdb_rating'] = None
                else:
                    df.at[idx, 'imdb_rating'] = None

            # --- Update Director (if missing) ---
            if not director_done:
                omdb_director = data.get('Director', '').strip()
                if omdb_director and omdb_director != 'N/A':
                    df.at[idx, 'director'] = omdb_director
                else:
                    df.at[idx, 'director'] = None

            print(f"✅ {title} ({year}) → "
                  f"Rating: {df.at[idx, 'imdb_rating']}, "
                  f"Director: {df.at[idx, 'director'] or 'N/A'}")

        else:
            error_msg = data.get('Error', 'Unknown error')
            print(f"❌ Not found: '{title}' ({year}) → Reason: {error_msg}")
            # Only set rating/director to None if we were trying to fetch them
            if not rating_done:
                df.at[idx, 'imdb_rating'] = None
            if not director_done:
                df.at[idx, 'director'] = None

            # 🔴 Stop on rate limit
            if error_msg == "Request limit reached!":
                print("\n🛑 OMDb daily request limit reached! Stopping.")
                df.to_csv(OUTPUT_FILE, index=False)
                print(f"✅ Final progress saved to {OUTPUT_FILE}")
                sys.exit(0)

        processed_count += 1
        time.sleep(1)  

    # 💾 Save progress periodically (including skipped rows)
    if processed_count % SAVE_EVERY == 0:
        df.to_csv(OUTPUT_FILE, index=False)
        print(f"💾 Saved progress at row {idx + 1} (every {SAVE_EVERY})")

# Final save
df.to_csv(OUTPUT_FILE, index=False)
print(f"\n✨ All done! Final results saved to {OUTPUT_FILE}")
# Out:
# 📁 Resuming from existing netflix_titles(modified_Final).csv
# ⏭️  Skipping (rating & director already present): Dick Johnson Is Dead
# ✅ Blood & Water (2021) → Rating: nan, Director: Clarence Horatio
# ⏭️  Skipping (rating & director already present): Ganglands
# ⏭️  Skipping (rating & director already present): Jailbirds New Orleans
# ❌ Not found: 'Kota Factory' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Midnight Mass
# ⏭️  Skipping (rating & director already present): My Little Pony: A New Generation
# ⏭️  Skipping (rating & director already present): Sankofa
# ⏭️  Skipping (rating & director already present): The Great British Baking Show
# ⏭️  Skipping (rating & director already present): The Starling
# 💾 Saved progress at row 10 (every 10)
# ❌ Not found: 'Vendetta: Truth, Lies and The Mafia' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Bangkok Breaking
# ⏭️  Skipping (rating & director already present): Je Suis Karl
# ⏭️  Skipping (rating & director already present): Confessions of an Invisible Girl
# ⏭️  Skipping (rating & director already present): Crime Stories: India Detectives
# ⏭️  Skipping (rating & director already present): Dear White People
# ⏭️  Skipping (rating & director already present): Europe's Most Dangerous Man: Otto Skorzeny in Spain
# ❌ Not found: 'Falsa identidad' (2020) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Intrusion
# ✅ Jaguar (2021) → Rating: 5.8, Director: N/A
# 💾 Saved progress at row 20 (every 10)
# ⏭️  Skipping (rating & director already present): Monsters Inside: The 24 Faces of Billy Milligan
# ❌ Not found: 'Resurrection: Ertugrul' (2018) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Avvai Shanmughi
# ✅ Go! Go! Cory Carson: Chrissy Takes the Wheel (2021) → Rating: nan, Director: Alex Woo, Stanley Moore
# ⏭️  Skipping (rating & director already present): Jeans
# ⏭️  Skipping (rating & director already present): Love on the Spectrum
# ❌ Not found: 'Minsara Kanavu' (1997) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Grown Ups
# ⏭️  Skipping (rating & director already present): Dark Skies
# ⏭️  Skipping (rating & director already present): Paranoia
# 💾 Saved progress at row 30 (every 10)
# ⏭️  Skipping (rating & director already present): Ankahi Kahaniya
# ✅ Chicago Party Aunt (2021) → Rating: 5.7, Director: N/A
# ⏭️  Skipping (rating & director already present): Sex Education
# ✅ Squid Game (2021) → Rating: 8.0, Director: N/A
# ✅ Tayo and Little Wizards (2020) → Rating: nan, Director: Gábor Fabricius
# ⏭️  Skipping (rating & director already present): The Father Who Moves Mountains
# ❌ Not found: 'The Stronghold' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Angry Birds
# ⏭️  Skipping (rating & director already present): Birth of the Dragon
# ✅ Chhota Bheem (2021) → Rating: nan, Director: Rajiv Chilaka
# 💾 Saved progress at row 40 (every 10)
# ⏭️  Skipping (rating & director already present): He-Man and the Masters of the Universe
# ⏭️  Skipping (rating & director already present): Jaws
# ⏭️  Skipping (rating & director already present): Jaws 2
# ⏭️  Skipping (rating & director already present): Jaws 3
# ⏭️  Skipping (rating & director already present): Jaws: The Revenge
# ⏭️  Skipping (rating & director already present): My Heroes Were Cowboys
# ⏭️  Skipping (rating & director already present): Safe House
# ⏭️  Skipping (rating & director already present): The Smart Money Woman
# ⏭️  Skipping (rating & director already present): Training Day
# ⏭️  Skipping (rating & director already present): Castle and Castle
# 💾 Saved progress at row 50 (every 10)
# ✅ Dharmakshetra (2014) → Rating: 8.5, Director: N/A
# ⏭️  Skipping (rating & director already present): InuYasha the Movie 2: The Castle Beyond the Looking Glass
# ⏭️  Skipping (rating & director already present): InuYasha the Movie 3: Swords of an Honorable Ruler
# ⏭️  Skipping (rating & director already present): InuYasha the Movie 4: Fire on the Mystic Island
# ⏭️  Skipping (rating & director already present): InuYasha the Movie: Affections Touching Across Time
# ⏭️  Skipping (rating & director already present): Nailed It
# ⏭️  Skipping (rating & director already present): Naruto Shippuden the Movie: Blood Prison
# ⏭️  Skipping (rating & director already present): Naruto Shippûden the Movie: Bonds
# ❌ Not found: 'Naruto Shippûden the Movie: The Will of Fire' (2009) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Naruto Shippuden: The Movie
# 💾 Saved progress at row 60 (every 10)
# ❌ Not found: 'Naruto Shippuden: The Movie: The Lost Tower' (2010) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Naruto the Movie 2: Legend of the Stone of Gelel
# ⏭️  Skipping (rating & director already present): Naruto the Movie 3: Guardians of the Crescent Moon Kingdom
# ⏭️  Skipping (rating & director already present): Naruto the Movie: Ninja Clash in the Land of Snow
# ⏭️  Skipping (rating & director already present): Nightbooks
# ⏭️  Skipping (rating & director already present): Numberblocks
# ❌ Not found: 'Raja Rasoi Aur Anya Kahaniyan' (2014) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Saved by the Bell
# ⏭️  Skipping (rating & director already present): Schumacher
# ⏭️  Skipping (rating & director already present): Stories by Rabindranath Tagore
# 💾 Saved progress at row 70 (every 10)
# ✅ Too Hot To Handle: Latino (2021) → Rating: 5.2, Director: N/A
# ✅ A StoryBots Space Adventure (2021) → Rating: nan, Director: David A. Vargas
# ⏭️  Skipping (rating & director already present): Jack Whitehall: Travels with My Father
# ⏭️  Skipping (rating & director already present): King of Boys
# ⏭️  Skipping (rating & director already present): The World's Most Amazing Vacation Rentals
# ⏭️  Skipping (rating & director already present): You vs. Wild: Out Cold
# ⏭️  Skipping (rating & director already present): Yowamushi Pedal
# ⏭️  Skipping (rating & director already present): Little Singham - Black Shadow
# ⏭️  Skipping (rating & director already present): Tughlaq Durbar
# ❌ Not found: 'Tughlaq Durbar (Telugu)' (2021) → Reason: Movie not found!
# 💾 Saved progress at row 80 (every 10)
# ❌ Not found: 'Firedrake the Silver Dragon' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Kate
# ✅ Lucifer (2021) → Rating: nan, Director: Romane Orlando Robb
# ✅ Metal Shop Masters (2021) → Rating: 5.7, Director: N/A
# ⏭️  Skipping (rating & director already present): Omo Ghetto: the Saga
# ❌ Not found: 'Pokémon Master Journeys: The Series' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Prey
# ⏭️  Skipping (rating & director already present): Titipo Titipo
# ⏭️  Skipping (rating & director already present): Blood Brothers: Malcolm X & Muhammad Ali
# ❌ Not found: 'Mighty Raju' (2017) → Reason: Movie not found!
# 💾 Saved progress at row 90 (every 10)
# ⏭️  Skipping (rating & director already present): Paradise Hills
# ⏭️  Skipping (rating & director already present): The Women and the Murderer
# ⏭️  Skipping (rating & director already present): Into the Night
# ⏭️  Skipping (rating & director already present): JJ+E
# ⏭️  Skipping (rating & director already present): Show Dogs
# ✅ The Circle (2021) → Rating: nan, Director: Javier Colón Ríos
# ⏭️  Skipping (rating & director already present): If I Leave Here Tomorrow: A Film About Lynyrd Skynyrd
# ✅ Kid Cosmic (2021) → Rating: 7.9, Director: N/A
# ✅ Octonauts: Above & Beyond (2021) → Rating: 7.2, Director: N/A
# ✅ On the Verge (2021) → Rating: 6.5, Director: N/A
# 💾 Saved progress at row 100 (every 10)
# ❌ Not found: 'Tobot Galaxy Detectives' (2019) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Untold: Breaking Point
# ⏭️  Skipping (rating & director already present): Countdown: Inspiration4 Mission to Space
# ⏭️  Skipping (rating & director already present): Shadow Parties
# ⏭️  Skipping (rating & director already present): Tayo the Little Bus
# ⏭️  Skipping (rating & director already present): Angamaly Diaries
# ❌ Not found: 'Bunk'd' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): A Champion Heart
# ⏭️  Skipping (rating & director already present): Dive Club
# ⏭️  Skipping (rating & director already present): La casa de papel
# 💾 Saved progress at row 110 (every 10)
# ⏭️  Skipping (rating & director already present): Money Heist: From Tokyo to Berlin
# ⏭️  Skipping (rating & director already present): Sharkdog
# ✅ Worth (2021) → Rating: nan, Director: Sara Colangelo
# ⏭️  Skipping (rating & director already present): Afterlife of the Party
# ⏭️  Skipping (rating & director already present): Anjaam
# ⏭️  Skipping (rating & director already present): Bright Star
# ⏭️  Skipping (rating & director already present): Dhanak
# ❌ Not found: 'Final Account' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Gurgaon
# ❌ Not found: 'Here and There' (2020) → Reason: Movie not found!
# 💾 Saved progress at row 120 (every 10)
# ❌ Not found: 'Heroes of Goo Jit Zu' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Hotel Del Luna
# ⏭️  Skipping (rating & director already present): In the Cut
# ✅ Luv Kushh (2012) → Rating: nan, Director: Robert J Permenter
# ❌ Not found: 'Pororo - The Little Penguin' (2013) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Q-Force
# ⏭️  Skipping (rating & director already present): Shikara
# ⏭️  Skipping (rating & director already present): A Cinderella Story
# ⏭️  Skipping (rating & director already present): Agatha Christie's Crooked House
# ⏭️  Skipping (rating & director already present): An Unfinished Life
# 💾 Saved progress at row 130 (every 10)
# ⏭️  Skipping (rating & director already present): Barbie Big City Big Dreams
# ❌ Not found: 'Blade Runner: The Final Cut' (1982) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Brave Animated Series
# ⏭️  Skipping (rating & director already present): Chappie
# ⏭️  Skipping (rating & director already present): Clear and Present Danger
# ⏭️  Skipping (rating & director already present): Cliffhanger
# ⏭️  Skipping (rating & director already present): Cold Mountain
# ⏭️  Skipping (rating & director already present): Crocodile Dundee in Los Angeles
# ⏭️  Skipping (rating & director already present): Dear John
# ⏭️  Skipping (rating & director already present): Do the Right Thing
# 💾 Saved progress at row 140 (every 10)
# ⏭️  Skipping (rating & director already present): El patrón, radiografía de un crimen
# ⏭️  Skipping (rating & director already present): Extraction
# ⏭️  Skipping (rating & director already present): Freedom Writers
# ⏭️  Skipping (rating & director already present): Green Lantern
# ⏭️  Skipping (rating & director already present): House Party
# ⏭️  Skipping (rating & director already present): House Party 2
# ⏭️  Skipping (rating & director already present): House Party 3
# ✅ How to Be a Cowboy (2021) → Rating: 7.4, Director: N/A
# ❌ Not found: 'HQ Barbers' (2020) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): I Got the Hook Up
# 💾 Saved progress at row 150 (every 10)
# ⏭️  Skipping (rating & director already present): In Too Deep
# ⏭️  Skipping (rating & director already present): Initial D
# ⏭️  Skipping (rating & director already present): Janoskians: Untold and Untrue
# ⏭️  Skipping (rating & director already present): Kid-E-Cats
# ⏭️  Skipping (rating & director already present): Kuroko's Basketball
# ⏭️  Skipping (rating & director already present): Labyrinth
# ⏭️  Skipping (rating & director already present): Letters to Juliet
# ⏭️  Skipping (rating & director already present): Level 16
# ⏭️  Skipping (rating & director already present): Love Don't Cost a Thing
# ⏭️  Skipping (rating & director already present): Love in a Puff
# 💾 Saved progress at row 160 (every 10)
# ⏭️  Skipping (rating & director already present): Major Dad
# ⏭️  Skipping (rating & director already present): Mars Attacks!
# ⏭️  Skipping (rating & director already present): Marshall
# ⏭️  Skipping (rating & director already present): My Boss's Daughter
# ⏭️  Skipping (rating & director already present): Mystery Men
# ⏭️  Skipping (rating & director already present): Oldsters
# ⏭️  Skipping (rating & director already present): Once Upon a Time in America
# ⏭️  Skipping (rating & director already present): Open Season 2
# ⏭️  Skipping (rating & director already present): Osmosis Jones
# ⏭️  Skipping (rating & director already present): Poseidon
# 💾 Saved progress at row 170 (every 10)
# ⏭️  Skipping (rating & director already present): Rhyme & Reason
# ⏭️  Skipping (rating & director already present): Same Kind of Different as Me
# ⏭️  Skipping (rating & director already present): School of Rock
# ⏭️  Skipping (rating & director already present): Snervous Tyler Oakley
# ⏭️  Skipping (rating & director already present): Tears of the Sun
# ⏭️  Skipping (rating & director already present): The Blue Lagoon
# ⏭️  Skipping (rating & director already present): The Golden Child
# ⏭️  Skipping (rating & director already present): The Guns of Navarone
# ⏭️  Skipping (rating & director already present): The Interview
# ⏭️  Skipping (rating & director already present): The Nutty Professor
# 💾 Saved progress at row 180 (every 10)
# ⏭️  Skipping (rating & director already present): The Nutty Professor II: The Klumps
# ⏭️  Skipping (rating & director already present): Turning Point: 9/11 and the War on Terror
# ⏭️  Skipping (rating & director already present): Welcome Home Roscoe Jenkins
# ⏭️  Skipping (rating & director already present): In the Line of Fire
# ⏭️  Skipping (rating & director already present): Sparking Joy
# ❌ Not found: 'Untold: Crime & Penalties' (2021) → Reason: Movie not found!
# ✅ Hometown Cha-Cha-Cha (2021) → Rating: 8.3, Director: N/A
# ⏭️  Skipping (rating & director already present): The Ingenuity of the Househusband
# ⏭️  Skipping (rating & director already present): 2 Alone in Paris
# ⏭️  Skipping (rating & director already present): Bread Barbershop
# 💾 Saved progress at row 190 (every 10)
# ⏭️  Skipping (rating & director already present): Thimmarusu
# ⏭️  Skipping (rating & director already present): Wind River
# ⏭️  Skipping (rating & director already present): C Kkompany
# ⏭️  Skipping (rating & director already present): D.P.
# ⏭️  Skipping (rating & director already present): Deadly Sins
# ⏭️  Skipping (rating & director already present): EMI: Liya Hai To Chukana Padega
# ⏭️  Skipping (rating & director already present): He's All That
# ⏭️  Skipping (rating & director already present): I Heart Arlo
# ⏭️  Skipping (rating & director already present): King of Boys: The Return of the King
# ❌ Not found: 'Koi Aap Sa' (2006) → Reason: Movie not found!
# 💾 Saved progress at row 200 (every 10)
# ⏭️  Skipping (rating & director already present): Krishna Cottage
# ⏭️  Skipping (rating & director already present): Kucch To Hai
# ⏭️  Skipping (rating & director already present): Kyaa Kool Hai Hum
# ⏭️  Skipping (rating & director already present): Kyaa Kool Hain Hum 3
# ⏭️  Skipping (rating & director already present): Kyaa Super Kool Hain Hum
# ⏭️  Skipping (rating & director already present): Kyo Kii... Main Jhuth Nahin Bolta
# ⏭️  Skipping (rating & director already present): LSD: Love, Sex Aur Dhokha
# ⏭️  Skipping (rating & director already present): Mission Istaanbul: Darr Ke Aagey Jeet Hai
# ⏭️  Skipping (rating & director already present): Once Upon a Time in Mumbaai
# ⏭️  Skipping (rating & director already present): Once Upon a Time in Mumbai Dobaara!
# 💾 Saved progress at row 210 (every 10)
# ⏭️  Skipping (rating & director already present): Ragini MMS
# ⏭️  Skipping (rating & director already present): Ragini MMS 2
# ⏭️  Skipping (rating & director already present): Rebellion
# ⏭️  Skipping (rating & director already present): RIDE ON TIME
# ⏭️  Skipping (rating & director already present): SAS: Rise of the Black Swan
# ⏭️  Skipping (rating & director already present): Shootout at Lokhandwala
# ⏭️  Skipping (rating & director already present): Shor In the City
# ⏭️  Skipping (rating & director already present): The Dirty Picture
# ✅ Titletown High (2021) → Rating: 5.8, Director: N/A
# ✅ EDENS ZERO (2021) → Rating: 7.1, Director: N/A
# 💾 Saved progress at row 220 (every 10)
# ⏭️  Skipping (rating & director already present): Family Reunion
# ⏭️  Skipping (rating & director already present): Bob Ross: Happy Accidents, Betrayal & Greed
# ⏭️  Skipping (rating & director already present): Clickbait
# ⏭️  Skipping (rating & director already present): John of God: The Crimes of a Spiritual Healer
# ⏭️  Skipping (rating & director already present): Motel Makeover
# ✅ Open Your Eyes (2021) → Rating: 6.6, Director: N/A
# ⏭️  Skipping (rating & director already present): Post Mortem: No One Dies in Skarnes
# ⏭️  Skipping (rating & director already present): Really Love
# ⏭️  Skipping (rating & director already present): The November Man
# ⏭️  Skipping (rating & director already present): The Old Ways
# 💾 Saved progress at row 230 (every 10)
# ⏭️  Skipping (rating & director already present): The River Runner
# ❌ Not found: 'The Water Man' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Wheel of Fortune
# ⏭️  Skipping (rating & director already present): Count Me In
# ⏭️  Skipping (rating & director already present): Oggy Oggy
# ⏭️  Skipping (rating & director already present): Untold: Caitlyn Jenner
# ⏭️  Skipping (rating & director already present): Boomika
# ❌ Not found: 'Boomika (Hindi)' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Boomika (Malayalam)
# ⏭️  Skipping (rating & director already present): Boomika (Telugu)
# 💾 Saved progress at row 240 (every 10)
# ⏭️  Skipping (rating & director already present): The Witcher: Nightmare of the Wolf
# ⏭️  Skipping (rating & director already present): Manifest
# ⏭️  Skipping (rating & director already present): Comedy Premium League
# ✅ Everything Will Be Fine (2021) → Rating: 6.3, Director: N/A
# ⏭️  Skipping (rating & director already present): Gunshot
# ⏭️  Skipping (rating & director already present): Korean Cold Noodle Rhapsody
# ⏭️  Skipping (rating & director already present): Man in Love
# ⏭️  Skipping (rating & director already present): Sweet Girl
# ⏭️  Skipping (rating & director already present): The Chair
# ⏭️  Skipping (rating & director already present): The Loud House Movie
# 💾 Saved progress at row 250 (every 10)
# ⏭️  Skipping (rating & director already present): A Faraway Land
# ⏭️  Skipping (rating & director already present): Like Crazy
# ⏭️  Skipping (rating & director already present): Black Island
# ⏭️  Skipping (rating & director already present): Bombay
# ⏭️  Skipping (rating & director already present): Go! Go! Cory Carson
# ⏭️  Skipping (rating & director already present): Memories of a Murderer: The Nilsen Tapes
# ⏭️  Skipping (rating & director already present): Nneka The Pretty Serpent
# ⏭️  Skipping (rating & director already present): O Kadhal Kanmani
# ⏭️  Skipping (rating & director already present): Out of my league
# ⏭️  Skipping (rating & director already present): Pahuna
# 💾 Saved progress at row 260 (every 10)
# ✅ The Defeated (2020) → Rating: 7.1, Director: N/A
# ⏭️  Skipping (rating & director already present): The Secret Diary of an Exchange Student
# ⏭️  Skipping (rating & director already present): Untold: Deal With the Devil
# ⏭️  Skipping (rating & director already present): Mother Goose Club
# ⏭️  Skipping (rating & director already present): Walk of Shame
# ⏭️  Skipping (rating & director already present): Rascal Does Not Dream of Bunny Girl Senpai
# ❌ Not found: 'The Creative Indians' (2020) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): The Piano
# ✅ Unroyal (2020) → Rating: nan, Director: Moses Inwang
# ❌ Not found: 'Winx Club' (2015) → Reason: Movie not found!
# 💾 Saved progress at row 270 (every 10)
# ⏭️  Skipping (rating & director already present): Beckett
# ⏭️  Skipping (rating & director already present): Brand New Cherry Flavor
# ❌ Not found: 'Fast & Furious Spy Racers' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Gone for Good
# ❌ Not found: 'Grace and Frankie' (2021) → Reason: Movie not found!
# ✅ The Kingdom (2021) → Rating: 6.4, Director: N/A
# ✅ Valeria (2021) → Rating: nan, Director: Inma Torrente
# ⏭️  Skipping (rating & director already present): AlRawabi School for Girls
# ⏭️  Skipping (rating & director already present): Lokillo: Nothing's the Same
# ⏭️  Skipping (rating & director already present): Monster Hunter: Legends of the Guild
# 💾 Saved progress at row 280 (every 10)
# ⏭️  Skipping (rating & director already present): Bake Squad
# ✅ Brother Jekwu (2016) → Rating: nan, Director: Charles Uwagbai
# ❌ Not found: 'La diosa del asfalto' (2020) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Misha and the Wolves
# ⏭️  Skipping (rating & director already present): The Kissing Booth 3
# ⏭️  Skipping (rating & director already present): The Railway Man
# ✅ Gabby's Dollhouse (2021) → Rating: 7.1, Director: N/A
# ⏭️  Skipping (rating & director already present): I Need Romance
# ❌ Not found: 'Las muñecas de la mafia' (2018) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): The Crowned Clown
# 💾 Saved progress at row 290 (every 10)
# ⏭️  Skipping (rating & director already present): Untold: Malice at the Palace
# ✅ SHAMAN KING (2021) → Rating: 6.9, Director: N/A
# ⏭️  Skipping (rating & director already present): Quartet
# ⏭️  Skipping (rating & director already present): Slay
# ⏭️  Skipping (rating & director already present): Takizawa Kabuki ZERO 2020 The Movie
# ⏭️  Skipping (rating & director already present): The Paper Tigers
# ✅ Hit & Run (2021) → Rating: 7.0, Director: N/A
# ⏭️  Skipping (rating & director already present): Navarasa
# ⏭️  Skipping (rating & director already present): Quam's Money
# ❌ Not found: 'The Swarm' (2021) → Reason: Movie not found!
# 💾 Saved progress at row 300 (every 10)
# ⏭️  Skipping (rating & director already present): Vivo
# ⏭️  Skipping (rating & director already present): Chennai Express
# ⏭️  Skipping (rating & director already present): City of God: 10 Years Later
# ⏭️  Skipping (rating & director already present): Esperando la carroza
# ⏭️  Skipping (rating & director already present): Lady Boss: The Jackie Collins Story
# ❌ Not found: 'Tango Feroz' (1993) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): '76
# ⏭️  Skipping (rating & director already present): Aftermath
# ⏭️  Skipping (rating & director already present): American Masters: Inventing David Geffen
# ⏭️  Skipping (rating & director already present): Car Masters: Rust to Riches
# 💾 Saved progress at row 310 (every 10)
# ⏭️  Skipping (rating & director already present): Cocaine Cowboys: The Kings of Miami
# ⏭️  Skipping (rating & director already present): Control Z
# ✅ Cooking With Paris (2021) → Rating: 5.4, Director: N/A
# ⏭️  Skipping (rating & director already present): Autumn's Concerto
# ⏭️  Skipping (rating & director already present): Heavy
# ⏭️  Skipping (rating & director already present): Ije: The Journey
# ⏭️  Skipping (rating & director already present): Office Girls
# ⏭️  Skipping (rating & director already present): Pray Away
# ⏭️  Skipping (rating & director already present): Shiny_Flakes: The Teenage Drug Lord
# ⏭️  Skipping (rating & director already present): The Prince Who Turns into a Frog
# 💾 Saved progress at row 320 (every 10)
# ✅ Top Secret UFO Projects: Declassified (2021) → Rating: 5.6, Director: N/A
# ⏭️  Skipping (rating & director already present): Two Fathers
# ❌ Not found: 'You're My Destiny' (2008) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): 30 Rock
# ⏭️  Skipping (rating & director already present): 44 Cats
# ⏭️  Skipping (rating & director already present): Beethoven
# ⏭️  Skipping (rating & director already present): Beethoven's 2nd
# ⏭️  Skipping (rating & director already present): Beowulf
# ⏭️  Skipping (rating & director already present): Boyka: Undisputed
# ⏭️  Skipping (rating & director already present): Catch Me If You Can
# 💾 Saved progress at row 330 (every 10)
# ⏭️  Skipping (rating & director already present): Cloudy with a Chance of Meatballs
# ✅ Darwin’s Game (2020) → Rating: 7.2, Director: N/A
# ⏭️  Skipping (rating & director already present): Deep Blue Sea
# ⏭️  Skipping (rating & director already present): Ferris Bueller's Day Off
# ⏭️  Skipping (rating & director already present): Five Feet Apart
# ⏭️  Skipping (rating & director already present): Freedomland
# ⏭️  Skipping (rating & director already present): Friday Night Lights
# ⏭️  Skipping (rating & director already present): Good Luck Chuck
# ❌ Not found: 'Hunter X Hunter (2011)' (2014) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): I missed you: Director's Cut
# 💾 Saved progress at row 340 (every 10)
# ⏭️  Skipping (rating & director already present): Inception
# ⏭️  Skipping (rating & director already present): Magnolia
# ⏭️  Skipping (rating & director already present): Major Payne
# ⏭️  Skipping (rating & director already present): My Girl
# ⏭️  Skipping (rating & director already present): My Girl 2
# ⏭️  Skipping (rating & director already present): Open Season: Scared Silly
# ⏭️  Skipping (rating & director already present): Pineapple Express
# ⏭️  Skipping (rating & director already present): Planet 51
# ⏭️  Skipping (rating & director already present): Poms
# ⏭️  Skipping (rating & director already present): Seabiscuit
# 💾 Saved progress at row 350 (every 10)
# ⏭️  Skipping (rating & director already present): Space Cowboys
# ⏭️  Skipping (rating & director already present): Team America: World Police
# ⏭️  Skipping (rating & director already present): The Edge of Seventeen
# ⏭️  Skipping (rating & director already present): The Haunting in Connecticut 2: Ghosts of Georgia
# ⏭️  Skipping (rating & director already present): The Last Boy Scout
# ⏭️  Skipping (rating & director already present): The Lincoln Lawyer
# ⏭️  Skipping (rating & director already present): The Losers
# ⏭️  Skipping (rating & director already present): The Machinist
# ⏭️  Skipping (rating & director already present): The Net
# ⏭️  Skipping (rating & director already present): The Original Kings of Comedy
# 💾 Saved progress at row 360 (every 10)
# ⏭️  Skipping (rating & director already present): Valentine's Day
# ✅ Charmed (2021) → Rating: 6.5, Director: N/A
# ⏭️  Skipping (rating & director already present): The Lost Café
# ⏭️  Skipping (rating & director already present): The Vault
# ✅ Centaurworld (2021) → Rating: 7.6, Director: N/A
# ⏭️  Skipping (rating & director already present): Eyes of a Thief
# ⏭️  Skipping (rating & director already present): Glow Up
# ⏭️  Skipping (rating & director already present): I'm Glad I Did
# ⏭️  Skipping (rating & director already present): Khawatir
# ⏭️  Skipping (rating & director already present): Myth & Mogul: John DeLorean
# 💾 Saved progress at row 370 (every 10)
# ⏭️  Skipping (rating & director already present): Outer Banks
# ⏭️  Skipping (rating & director already present): Pomegranates and Myrrh
# ⏭️  Skipping (rating & director already present): Rurouni Kenshin: The Beginning
# ⏭️  Skipping (rating & director already present): The Last Mercenary
# ⏭️  Skipping (rating & director already present): Flower Girl
# ⏭️  Skipping (rating & director already present): Resort to Love
# ⏭️  Skipping (rating & director already present): Transformers: War for Cybertron: Kingdom
# ⏭️  Skipping (rating & director already present): Bartkowiak
# ⏭️  Skipping (rating & director already present): Fantastic Fungi
# ✅ Tattoo Redo (2021) → Rating: 5.9, Director: N/A
# 💾 Saved progress at row 380 (every 10)
# ❌ Not found: 'The Flash' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): The Snitch Cartel: Origins
# ❌ Not found: 'All American' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Department
# ⏭️  Skipping (rating & director already present): Hostage House
# ❌ Not found: 'How to Sell Drugs Online (Fast)' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Mighty Express
# ⏭️  Skipping (rating & director already present): Mimi
# ⏭️  Skipping (rating & director already present): Plastic Cup Boyz: Laughing My Mask Off!
# ⏭️  Skipping (rating & director already present): The Operative
# 💾 Saved progress at row 390 (every 10)
# ⏭️  Skipping (rating & director already present): The Walking Dead
# ⏭️  Skipping (rating & director already present): Wynonna Earp
# ⏭️  Skipping (rating & director already present): Django Unchained
# ⏭️  Skipping (rating & director already present): A Second Chance:  Rivals!
# ⏭️  Skipping (rating & director already present): African America
# ⏭️  Skipping (rating & director already present): Bankrolled
# ⏭️  Skipping (rating & director already present): Blood Red Sky
# ⏭️  Skipping (rating & director already present): Feels Like Ishq
# ⏭️  Skipping (rating & director already present): Kingdom: Ashin of the North
# ✅ Masters of the Universe: Revelation (2021) → Rating: 5.6, Director: N/A
# 💾 Saved progress at row 400 (every 10)
# ⏭️  Skipping (rating & director already present): Revelations: The Masters of the Universe: Revelation Aftershow
# ⏭️  Skipping (rating & director already present): Sky Rojo
# ⏭️  Skipping (rating & director already present): The Last Letter From Your Lover
# ⏭️  Skipping (rating & director already present): The Movies That Made Us
# ❌ Not found: '9to5: The Story of a Movement' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Chhota Bheem - Dinosaur World
# ⏭️  Skipping (rating & director already present): Chhota Bheem - Neeli Pahaadi
# ❌ Not found: 'Chhota Bheem & Ganesh' (2009) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Chhota Bheem & Krishna: Mayanagari
# ⏭️  Skipping (rating & director already present): Chhota Bheem & Krishna: Pataliputra- City of the Dead
# 💾 Saved progress at row 410 (every 10)
# ❌ Not found: 'Chhota Bheem And The Broken Amulet' (2013) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Chhota Bheem And The Crown of Valhalla
# ❌ Not found: 'Chhota Bheem and the Incan Adventure' (2013) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Chhota Bheem and The ShiNobi Secret
# ⏭️  Skipping (rating & director already present): Chhota Bheem Aur Hanuman
# ⏭️  Skipping (rating & director already present): Chhota Bheem aur Krishna
# ⏭️  Skipping (rating & director already present): Chhota Bheem aur Krishna vs Zimbara
# ⏭️  Skipping (rating & director already present): Chhota Bheem in African Safari
# ✅ Chhota Bheem Ka Roosi Romanch (2019) → Rating: nan, Director: Arpan Sarkar, Shyamal Chaulia
# ⏭️  Skipping (rating & director already present): Chhota Bheem: Bheem vs Aliens
# 💾 Saved progress at row 420 (every 10)
# ⏭️  Skipping (rating & director already present): Chhota Bheem: Dholakpur to Kathmandu
# ⏭️  Skipping (rating & director already present): Chhota Bheem: Dus Pe Dus
# ⏭️  Skipping (rating & director already present): Chhota Bheem: Journey to Petra
# ⏭️  Skipping (rating & director already present): Chhota Bheem: Master of Shaolin
# ❌ Not found: 'Chhota Bheem: The Rise of Kirmada' (2012) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Chicago Med
# ⏭️  Skipping (rating & director already present): Cousins
# ⏭️  Skipping (rating & director already present): Wannabe Courageous
# ⏭️  Skipping (rating & director already present): Words Bubble Up Like Soda Pop
# ⏭️  Skipping (rating & director already present): Sanitation Day
# 💾 Saved progress at row 430 (every 10)
# ✅ Sexy Beasts (2021) → Rating: 4.7, Director: N/A
# ⏭️  Skipping (rating & director already present): Too Hot to Handle: Brazil
# ⏭️  Skipping (rating & director already present): Trollhunters: Rise of the Titans
# ⏭️  Skipping (rating & director already present): Milkwater
# ⏭️  Skipping (rating & director already present): Okupas
# ⏭️  Skipping (rating & director already present): Touch Your Heart
# ❌ Not found: 'The Tambour of Retribution' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Cosmic Sin
# ❌ Not found: '2 Weeks in Lagos' (2020) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Deep
# 💾 Saved progress at row 440 (every 10)
# ✅ Explained (2021) → Rating: 7.0, Director: N/A
# ⏭️  Skipping (rating & director already present): Fear Street Part 3: 1666
# ⏭️  Skipping (rating & director already present): Johnny Test
# ⏭️  Skipping (rating & director already present): La ley de Herodes
# ⏭️  Skipping (rating & director already present): Naomi Osaka
# ⏭️  Skipping (rating & director already present): The Beguiled
# ⏭️  Skipping (rating & director already present): The Book of Henry
# ⏭️  Skipping (rating & director already present): The Twilight Saga: Breaking Dawn: Part 1
# ⏭️  Skipping (rating & director already present): The Twilight Saga: Breaking Dawn: Part 2
# ⏭️  Skipping (rating & director already present): The Twilight Saga: Eclipse
# 💾 Saved progress at row 450 (every 10)
# ⏭️  Skipping (rating & director already present): The Twilight Saga: New Moon
# ⏭️  Skipping (rating & director already present): Twilight
# ⏭️  Skipping (rating & director already present): A Perfect Fit
# ⏭️  Skipping (rating & director already present): BEASTARS
# ❌ Not found: 'Cheech & Chong's Still Smokin' (1983) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Emicida: AmarElo - Live in São Paulo
# ⏭️  Skipping (rating & director already present): Her Private Life
# ⏭️  Skipping (rating & director already present): Lift Like a Girl
# ⏭️  Skipping (rating & director already present): My Amanda
# ⏭️  Skipping (rating & director already present): Never Have I Ever
# 💾 Saved progress at row 460 (every 10)
# ⏭️  Skipping (rating & director already present): Surf's Up
# ⏭️  Skipping (rating & director already present): The Unknown Saint
# ⏭️  Skipping (rating & director already present): This Changes Everything
# ⏭️  Skipping (rating & director already present): A Classic Horror Story
# ⏭️  Skipping (rating & director already present): Gunpowder Milkshake
# ⏭️  Skipping (rating & director already present): Heist
# ⏭️  Skipping (rating & director already present): My Unorthodox Life
# ⏭️  Skipping (rating & director already present): Private Network: Who Killed Manuel Buendía?
# ⏭️  Skipping (rating & director already present): The Guide to the Perfect Family
# ⏭️  Skipping (rating & director already present): American Woman
# 💾 Saved progress at row 470 (every 10)
# ❌ Not found: 'Bridgerton - The Afterparty' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Day of Destiny
# ✅ Ridley Jones (2021) → Rating: 2.0, Director: N/A
# ⏭️  Skipping (rating & director already present): Born to Play
# ⏭️  Skipping (rating & director already present): American Ultra
# ⏭️  Skipping (rating & director already present): The Stand-Up
# ⏭️  Skipping (rating & director already present): The Tour
# ⏭️  Skipping (rating & director already present): Atypical
# ⏭️  Skipping (rating & director already present): Biohackers
# ❌ Not found: 'Fear Street Part 2: 1978' (2021) → Reason: Movie not found!
# 💾 Saved progress at row 480 (every 10)
# ⏭️  Skipping (rating & director already present): Finding Hubby
# ⏭️  Skipping (rating & director already present): How I Became a Superhero
# ⏭️  Skipping (rating & director already present): How to Become a Tyrant
# ⏭️  Skipping (rating & director already present): Last Summer
# ⏭️  Skipping (rating & director already present): Lee Su-geun: The Sense Coach
# ⏭️  Skipping (rating & director already present): Lethal Love
# ⏭️  Skipping (rating & director already present): Ratchet and Clank
# ✅ The Cook of Castamar (2021) → Rating: 7.4, Director: N/A
# ❌ Not found: 'Virgin River' (2021) → Reason: Movie not found!
# ✅ Back to Q82 (2017) → Rating: nan, Director: Ahmed Siddiqui
# 💾 Saved progress at row 490 (every 10)
# ⏭️  Skipping (rating & director already present): Elize Matsunaga: Once Upon a Crime
# ⏭️  Skipping (rating & director already present): Home Again
# ⏭️  Skipping (rating & director already present): Midnight Sun
# ⏭️  Skipping (rating & director already present): RESIDENT EVIL: Infinite Darkness
# ⏭️  Skipping (rating & director already present): Rock the Kasbah
# ⏭️  Skipping (rating & director already present): Awon Boyz
# ⏭️  Skipping (rating & director already present): Brick Mansions
# ✅ Cat People (2021) → Rating: 6.5, Director: N/A
# ⏭️  Skipping (rating & director already present): Clash
# ⏭️  Skipping (rating & director already present): Dogs
# 💾 Saved progress at row 500 (every 10)
# ⏭️  Skipping (rating & director already present): Major Grom: Plague Doctor
# ✅ Mama Drama (2020) → Rating: nan, Director: Seyi Babatope
# ⏭️  Skipping (rating & director already present): Tango With Me
# ⏭️  Skipping (rating & director already present): The Mire
# ⏭️  Skipping (rating & director already present): The War Next-door
# ⏭️  Skipping (rating & director already present): Therapy
# ⏭️  Skipping (rating & director already present): This Little Love Of Mine
# ✅ Three Thieves (2019) → Rating: nan, Director: Udoka Oyeka
# ❌ Not found: 'A Land Imagined' (2019) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Ask the StoryBots
# 💾 Saved progress at row 510 (every 10)
# ⏭️  Skipping (rating & director already present): Between
# ✅ Chelsea (2017) → Rating: nan, Director: Jared Bentley
# ❌ Not found: 'Code Lyoko' (2007) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Colony
# ✅ Cuckoo (2019) → Rating: nan, Director: Anna Fiscus
# ✅ Derry Girls (2019) → Rating: nan, Director: N/A
# ✅ Girl from Nowhere (2021) → Rating: nan, Director: Suzie Philippot
# ⏭️  Skipping (rating & director already present): Good Morning Call
# ⏭️  Skipping (rating & director already present): Har Kisse Ke Hisse: Kaamyaab
# ⏭️  Skipping (rating & director already present): I AM A KILLER
# 💾 Saved progress at row 520 (every 10)
# ❌ Not found: 'I Think You Should Leave with Tim Robinson' (2021) → Reason: Movie not found!
# ❌ Not found: 'Kim's Convenience' (2021) → Reason: Movie not found!
# ❌ Not found: 'Larva' (2015) → Reason: Movie not found!
# ❌ Not found: 'Marcella' (2019) → Reason: Movie not found!
# ❌ Not found: 'Midnight Diner: Tokyo Stories' (2019) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): My Little Pony: Friendship Is Magic
# ⏭️  Skipping (rating & director already present): Orange Is the New Black
# ⏭️  Skipping (rating & director already present): Puffin Rock
# ⏭️  Skipping (rating & director already present): Rehmataan
# ⏭️  Skipping (rating & director already present): Return of the Prodigal Son
# 💾 Saved progress at row 530 (every 10)
# ⏭️  Skipping (rating & director already present): Richie Rich
# ⏭️  Skipping (rating & director already present): Rise: Ini Kalilah
# ⏭️  Skipping (rating & director already present): Scream
# ❌ Not found: 'Shtisel' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Si Doel the Movie 2
# ⏭️  Skipping (rating & director already present): Some Assembly Required
# ❌ Not found: 'Tales by Light' (2018) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Terrace House: Opening New Doors
# ⏭️  Skipping (rating & director already present): The A List
# ⏭️  Skipping (rating & director already present): The New Legends of Monkey
# 💾 Saved progress at row 540 (every 10)
# ❌ Not found: 'The Worst Witch' (2020) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Truckbhar Swapna
# ⏭️  Skipping (rating & director already present): Ujala
# ⏭️  Skipping (rating & director already present): Undercover
# ⏭️  Skipping (rating & director already present): Workin' Moms
# ❌ Not found: 'YooHoo to the Rescue' (2020) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): You Are My Spring
# ⏭️  Skipping (rating & director already present): We the People
# ✅ Grey's Anatomy (2020) → Rating: nan, Director: Chris Stuckmann
# ⏭️  Skipping (rating & director already present): Big Timber
# 💾 Saved progress at row 550 (every 10)
# ❌ Not found: 'Fear Street Part 1: 1994' (2021) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Haseen Dillruba
# ⏭️  Skipping (rating & director already present): Holiday on Mars
# ⏭️  Skipping (rating & director already present): Mortel
# ⏭️  Skipping (rating & director already present): RattleSnake - The Ahanna Story
# ⏭️  Skipping (rating & director already present): Snowpiercer
# ⏭️  Skipping (rating & director already present): The 8th Night
# ⏭️  Skipping (rating & director already present): Winchester
# ⏭️  Skipping (rating & director already present): 6 Bullets
# ⏭️  Skipping (rating & director already present): Air Force One
# 💾 Saved progress at row 560 (every 10)
# ⏭️  Skipping (rating & director already present): Audible
# ⏭️  Skipping (rating & director already present): Austin Powers in Goldmember
# ⏭️  Skipping (rating & director already present): Austin Powers: International Man of Mystery
# ⏭️  Skipping (rating & director already present): Austin Powers: The Spy Who Shagged Me
# ⏭️  Skipping (rating & director already present): Boogie Nights
# ⏭️  Skipping (rating & director already present): Bureau of Magical Things
# ⏭️  Skipping (rating & director already present): Charlie's Angels
# ⏭️  Skipping (rating & director already present): Congo
# ⏭️  Skipping (rating & director already present): Dennis the Menace
# ⏭️  Skipping (rating & director already present): Dreamy Eyes
# 💾 Saved progress at row 570 (every 10)
# ⏭️  Skipping (rating & director already present): Dynasty Warriors
# ✅ Generation 56k (2021) → Rating: 7.3, Director: N/A
# ✅ Hampstead (2019) → Rating: nan, Director: Joel Hopkins
# ⏭️  Skipping (rating & director already present): Kung Fu Panda
# ⏭️  Skipping (rating & director already present): Kung Fu Panda 2
# ⏭️  Skipping (rating & director already present): Life as We Know It
# ❌ Not found: 'Mary Magdalene' (2019) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Masameer County
# ⏭️  Skipping (rating & director already present): Memoirs of a Geisha
# ⏭️  Skipping (rating & director already present): Midnight Run
# 💾 Saved progress at row 580 (every 10)
# ⏭️  Skipping (rating & director already present): Mobile Suit Gundam Hathaway
# ⏭️  Skipping (rating & director already present): Mortal Kombat
# ⏭️  Skipping (rating & director already present): Mother's Day
# ⏭️  Skipping (rating & director already present): No Strings Attached
# ⏭️  Skipping (rating & director already present): Not Another Teen Movie
# ⏭️  Skipping (rating & director already present): Ophelia
# ⏭️  Skipping (rating & director already present): Pet Sematary 2
# ⏭️  Skipping (rating & director already present): Quarantine Tales
# ⏭️  Skipping (rating & director already present): Rainbow Rangers
# ❌ Not found: 'Red Joan' (2019) → Reason: Movie not found!
# 💾 Saved progress at row 590 (every 10)
# ⏭️  Skipping (rating & director already present): Sailor Moon Crystal
# ⏭️  Skipping (rating & director already present): Seven Pounds
# ⏭️  Skipping (rating & director already present): She's Out of My League
# ⏭️  Skipping (rating & director already present): Snow Day
# ⏭️  Skipping (rating & director already present): Star Trek
# ⏭️  Skipping (rating & director already present): Stuart Little
# ⏭️  Skipping (rating & director already present): Sword of Trust
# ⏭️  Skipping (rating & director already present): Talladega Nights: The Ballad of Ricky Bobby
# ⏭️  Skipping (rating & director already present): The American
# ⏭️  Skipping (rating & director already present): The Best of Enemies
# 💾 Saved progress at row 600 (every 10)
# ⏭️  Skipping (rating & director already present): The Game
# ⏭️  Skipping (rating & director already present): The Karate Kid
# ⏭️  Skipping (rating & director already present): The Karate Kid Part II
# ⏭️  Skipping (rating & director already present): The Karate Kid Part III
# ⏭️  Skipping (rating & director already present): The Life of David Gale
# ⏭️  Skipping (rating & director already present): The Long Riders
# ⏭️  Skipping (rating & director already present): The Queen
# ⏭️  Skipping (rating & director already present): The Strangers
# ⏭️  Skipping (rating & director already present): The Sum of All Fears
# ⏭️  Skipping (rating & director already present): The Tourist
# 💾 Saved progress at row 610 (every 10)
# ⏭️  Skipping (rating & director already present): Underworld
# ⏭️  Skipping (rating & director already present): Underworld: Awakening
# ⏭️  Skipping (rating & director already present): Underworld: Rise of the Lycans
# ⏭️  Skipping (rating & director already present): Voiceless
# ⏭️  Skipping (rating & director already present): What Dreams May Come
# ⏭️  Skipping (rating & director already present): Why Do Fools Fall in Love
# ⏭️  Skipping (rating & director already present): Working Title
# ✅ Young Royals (2021) → Rating: 8.2, Director: N/A
# ⏭️  Skipping (rating & director already present): America: The Motion Picture
# ⏭️  Skipping (rating & director already present): Deranged
# 💾 Saved progress at row 620 (every 10)
# ❌ Not found: 'Droppin' Cash: Los Angeles' (2019) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Legend of Exorcism
# ⏭️  Skipping (rating & director already present): Lying and Stealing
# ⏭️  Skipping (rating & director already present): Mommy Issues
# ⏭️  Skipping (rating & director already present): Prime Time
# ✅ Somos. (2021) → Rating: 7.1, Director: N/A
# ⏭️  Skipping (rating & director already present): Sophie: A Murder in West Cork
# ⏭️  Skipping (rating & director already present): The Daily Life of the Immortal King
# ⏭️  Skipping (rating & director already present): StarBeam
# ⏭️  Skipping (rating & director already present): A Way Back Home
# 💾 Saved progress at row 630 (every 10)
# ⏭️  Skipping (rating & director already present): Killing Them Softly
# ⏭️  Skipping (rating & director already present): The Seven Deadly Sins
# ✅ Wanted (2019) → Rating: nan, Director: Nibal Arakji
# ⏭️  Skipping (rating & director already present): Into the Wind
# ⏭️  Skipping (rating & director already present): Wonder Boy
# ⏭️  Skipping (rating & director already present): Here Comes the Rain
# ⏭️  Skipping (rating & director already present): The Ice Road
# ⏭️  Skipping (rating & director already present): Ray
# ⏭️  Skipping (rating & director already present): Sex/Life
# ✅ Godzilla Singular Point (2021) → Rating: 6.5, Director: N/A
# 💾 Saved progress at row 640 (every 10)
# ✅ Jiva! (2021) → Rating: 6.0, Director: N/A
# ⏭️  Skipping (rating & director already present): Sisters on Track
# ⏭️  Skipping (rating & director already present): The Naked Director
# ⏭️  Skipping (rating & director already present): The Seventh Day
# ⏭️  Skipping (rating & director already present): Good on Paper
# ⏭️  Skipping (rating & director already present): Murder by the Coast
# ⏭️  Skipping (rating & director already present): The House of Flowers: The Movie
# ⏭️  Skipping (rating & director already present): The Parisian Agency: Exclusive Properties
# ✅ Too Hot to Handle (2021) → Rating: 5.4, Director: N/A
# ⏭️  Skipping (rating & director already present): Broken
# 💾 Saved progress at row 650 (every 10)
# ⏭️  Skipping (rating & director already present): O Vendedor de Sonhos
# ⏭️  Skipping (rating & director already present): Osuofia in London
# ⏭️  Skipping (rating & director already present): Osuofia in London II
# ⏭️  Skipping (rating & director already present): This Is Pop
# ⏭️  Skipping (rating & director already present): #Selfie
# ⏭️  Skipping (rating & director already present): #Selfie 69
# ⏭️  Skipping (rating & director already present): Love Is a Story
# ✅ The Mole (2001) → Rating: 7.4, Director: N/A
# ✅ Nevertheless, (2021) → Rating: 7.1, Director: N/A
# ⏭️  Skipping (rating & director already present): Bangkok Love Stories: Innocence
# 💾 Saved progress at row 660 (every 10)
# ✅ Black Lightning (2021) → Rating: nan, Director: Carl Boisson
# ❌ Not found: 'Call My Agent!' (2018) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Champions
# ⏭️  Skipping (rating & director already present): Charité at War
# ❌ Not found: 'Cleo & Cuquin' (2020) → Reason: Movie not found!
# ...
# ⏭️  Skipping (rating & director already present): Life of An Outcast
# ⏭️  Skipping (rating & director already present): The Photographer Of Mauthausen
# ⏭️  Skipping (rating & director already present): Bert Kreischer: The Machine
# ❌ Not found: 'Chef's Table' (2019) → Reason: Movie not found!
# ✅ Firebrand (2019) → Rating: 5.2, Director: Aruna Raje
# ⏭️  Skipping (rating & director already present): Paddleton
# ⏭️  Skipping (rating & director already present): Paris Is Us
# ✅ Shonar Pahar (2018) → Rating: 8.1, Director: Parambrata Chatterjee
# ❌ Not found: 'The Big Family Cooking Showdown' (2018) → Reason: Movie not found!
# 💾 Saved progress at row 4090 (every 10)
# ⏭️  Skipping (rating & director already present): Z4
# ✅ The Drug King (2018) → Rating: 6.2, Director: Woo Min-ho
# ⏭️  Skipping (rating & director already present): Kevin James: Sweat the Small Stuff
# ⏭️  Skipping (rating & director already present): Transformer
# ✅ Genius (2018) → Rating: 5.1, Director: Suseenthiran
# ⏭️  Skipping (rating & director already present): Black Sea
# ✅ Studio 54 (2018) → Rating: 7.0, Director: Matt Tyrnauer
# ⏭️  Skipping (rating & director already present): Awe
# ⏭️  Skipping (rating & director already present): Ayana
# ⏭️  Skipping (rating & director already present): Behind the Curve
# 💾 Saved progress at row 4100 (every 10)
# ✅ Buddies (2012) → Rating: 6.5, Director: Marcelo Galvão
# ✅ Candyflip (2017) → Rating: 5.1, Director: Shanawaz Nellikunnil
# ❌ Not found: 'Chameli' (2004) → Reason: Movie not found!
# ✅ Fatso (2012) → Rating: nan, Director: Rajat Kapoor
# ⏭️  Skipping (rating & director already present): Hjørdis
# ⏭️  Skipping (rating & director already present): Larry Charles' Dangerous World of Comedy
# ⏭️  Skipping (rating & director already present): Neevevaro
# ✅ Pyaar Ke Side Effects (2006) → Rating: 6.8, Director: Saket Chaudhary
# ⏭️  Skipping (rating & director already present): Sur: The Melody of Life
# ⏭️  Skipping (rating & director already present): The 43
# 💾 Saved progress at row 4110 (every 10)
# ✅ The Breaker Upperers (2018) → Rating: 5.9, Director: Jackie van Beek, Madeleine Sami
# ⏭️  Skipping (rating & director already present): The Kirlian Frequency
# ⏭️  Skipping (rating & director already present): Ugly Aur Pagli
# ✅ Yucatán (2018) → Rating: nan, Director: Daniel Monzón
# ⏭️  Skipping (rating & director already present): Barbie Dreamhouse Adventures
# ⏭️  Skipping (rating & director already present): Ken Jeong: You Complete Me, Ho
# ❌ Not found: 'Velvet Colección' (2018) → Reason: Movie not found!
# ✅ Period. End of Sentence. (2018) → Rating: 7.4, Director: Rayka Zehtabchi
# ⏭️  Skipping (rating & director already present): Iron Ladies
# ⏭️  Skipping (rating & director already present): The Break
# 💾 Saved progress at row 4120 (every 10)
# ⏭️  Skipping (rating & director already present): High Flying Bird
# ⏭️  Skipping (rating & director already present): Kevin Hart's Guide to Black History
# ❌ Not found: 'One Day at a Time' (2019) → Reason: Movie not found!
# ✅ ReMastered: The Two Killings of Sam Cooke (2019) → Rating: 7.2, Director: Kelly Duane de la Vega
# ⏭️  Skipping (rating & director already present): The Tree of Blood
# ❌ Not found: 'The Last of the Schmucks' (2017) → Reason: Movie not found!
# ✅ Hidden Worlds (2018) → Rating: 7.1, Director: N/A
# ⏭️  Skipping (rating & director already present): Live
# ✅ Ray Romano: Right Here, Around the Corner (2019) → Rating: 7.2, Director: Michael Showalter
# ✅ Safe (2018) → Rating: 7.2, Director: Anand Kumar Dubey
# 💾 Saved progress at row 4130 (every 10)
# ❌ Not found: 'Tayee' (2018) → Reason: Movie not found!
# ✅ Violet Evergarden (2018) → Rating: 8.4, Director: Antje Behr, Marie Villetelle, Claudia Euen, Hai-Hsin Lu, Franziska Wielandt, Kristof Kannegiesser, Alba Vivancos Folch, Isabel Hahn, Anne-Sophie Jakubetz, Anne Pütz
# ✅ Romance is a bonus book (2019) → Rating: 8.0, Director: Gudrun Scheerer
# ⏭️  Skipping (rating & director already present): Await Further Instructions
# ⏭️  Skipping (rating & director already present): Manusangada
# ⏭️  Skipping (rating & director already present): 14 Minutes from Earth
# ✅ Dear Ex (2018) → Rating: 7.3, Director: Hsu Chih-yen, Mag Hsu
# ❌ Not found: 'Free Rein: Valentine's Day' (2019) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Lego DC Comics: Batman Be-Leaguered
# ⏭️  Skipping (rating & director already present): LEGO Marvel Super Heroes: Black Panther
# 💾 Saved progress at row 4140 (every 10)
# ✅ LEGO Marvel Super Heroes: Guardians of the Galaxy (2017) → Rating: 5.8, Director: Yamata41
# ⏭️  Skipping (rating & director already present): Littlest Pet Shop: A World of Our Own
# ⏭️  Skipping (rating & director already present): Russian Doll
# ✅ Sparta (2018) → Rating: 6.1, Director: Sade Ferguson
# ✅ Sword Art Online Alternative: Gun Gale Online (2018) → Rating: 6.8, Director: N/A
# ⏭️  Skipping (rating & director already present): True: Happy Hearts Day
# ⏭️  Skipping (rating & director already present): Velvet Buzzsaw
# ✅ Hantu Kak Limah (2018) → Rating: 5.6, Director: Mamat Khalid
# ✅ Love Off the Cuff (2017) → Rating: 6.5, Director: Pang Ho-cheung
# ✅ Paprika (2018) → Rating: 8.4, Director: N/A
# 💾 Saved progress at row 4150 (every 10)
# ⏭️  Skipping (rating & director already present): Maharaja: The Story of Ranjit Singh
# ⏭️  Skipping (rating & director already present): Virsa
# ⏭️  Skipping (rating & director already present): Bhasmasur
# ❌ Not found: 'Gabriel "Fluffy" Iglesias: One Show Fits All' (2019) → Reason: Movie not found!
# ✅ High Society (2018) → Rating: 5.6, Director: Byun Hyuk
# ✅ Up Among  The Stars (2018) → Rating: 6.3, Director: Zoe Berriatúa
# ⏭️  Skipping (rating & director already present): Alt-Right: Age of Rage
# ⏭️  Skipping (rating & director already present): Habibie & Ainun
# ⏭️  Skipping (rating & director already present): Nathicharami
# ✅ Rudy Habibie (2016) → Rating: 7.5, Director: Hanung Bramantyo
# 💾 Saved progress at row 4160 (every 10)
# ⏭️  Skipping (rating & director already present): Surga Yang Tak Dirindukan
# ⏭️  Skipping (rating & director already present): Surga Yang Tak Dirindukan 2
# ❌ Not found: 'A Taiwanese Tale of Two Cities' (2018) → Reason: Movie not found!
# ❌ Not found: 'Z Nation' (2018) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Goyo: The Boy General
# ✅ Animas (2018) → Rating: 4.9, Director: Laura Alvea, José Ortuño
# ✅ Black Earth Rising (2018) → Rating: 7.5, Director: Hugo Blick
# ⏭️  Skipping (rating & director already present): Club of Crows
# ✅ Examination of Conscience (2019) → Rating: 7.7, Director: N/A
# ⏭️  Skipping (rating & director already present): Mi Obra Maestra
# 💾 Saved progress at row 4170 (every 10)
# ⏭️  Skipping (rating & director already present): Polar
# ✅ The Perfect Match (2017) → Rating: 7.2, Director: N/A
# ⏭️  Skipping (rating & director already present): Conversations with a Killer: The Ted Bundy Tapes
# ✅ Just Love (2018) → Rating: nan, Director: Andy Caballero, Diego Corsini
# ⏭️  Skipping (rating & director already present): Innocent
# ⏭️  Skipping (rating & director already present): Close
# ❌ Not found: 'FYRE: The Greatest Party That Never Happened' (2019) → Reason: Movie not found!
# ✅ IO (2019) → Rating: 4.8, Director: Jonathan Helpert
# ❌ Not found: 'Marvel's The Punisher' (2019) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Memory Love
# 💾 Saved progress at row 4180 (every 10)
# ❌ Not found: 'Old Lord Savanna' (2018) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Patria
# ⏭️  Skipping (rating & director already present): Soni
# ❌ Not found: 'The World's Most Extraordinary Homes' (2019) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Trigger Warning with Killer Mike
# ✅ Abducted in Plain Sight (2017) → Rating: 6.8, Director: Skye Borgman
# ⏭️  Skipping (rating & director already present): Abdullah, The Final Witness
# ✅ Adhugo (2018) → Rating: 5.9, Director: Dylan Damian, Katie McCall
# ❌ Not found: 'Echcharikkai' (2018) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Lavender
# 💾 Saved progress at row 4190 (every 10)
# ✅ Pandigai (2017) → Rating: 6.4, Director: Feroz
# ✅ Pari (2018) → Rating: 6.6, Director: Syed Atif Ali
# ✅ Revenger (2018) → Rating: 5.7, Director: Lee Seung-won
# ✅ Sebastian Maniscalco: Stay Hungry (2019) → Rating: 7.1, Director: Rik Reinholdtsen
# ⏭️  Skipping (rating & director already present): The Doll
# ⏭️  Skipping (rating & director already present): The Doll 2
# ⏭️  Skipping (rating & director already present): La Grande Chaumière Violette
# ⏭️  Skipping (rating & director already present): Baazaar
# ⏭️  Skipping (rating & director already present): All of You
# ✅ Back with the Ex (2018) → Rating: 6.2, Director: Brandon Baker
# 💾 Saved progress at row 4200 (every 10)
# ❌ Not found: 'Friends from College' (2019) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Hardy Bucks
# ✅ Horrid Henry (2019) → Rating: 8.6, Director: Stephen Lategan
# ⏭️  Skipping (rating & director already present): ReMastered: Massacre at the Stadium
# ⏭️  Skipping (rating & director already present): Solo
# ⏭️  Skipping (rating & director already present): The Last Laugh
# ❌ Not found: 'Pocoyo' (2017) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): When Heroes Fly
# ✅ GODZILLA The Planet Eater (2018) → Rating: 5.1, Director: Kobun Shizuno, Hiroyuki Seshita
# ✅ Next Enti? (2018) → Rating: 4.3, Director: Kunal Kohli
# 💾 Saved progress at row 4210 (every 10)
# ✅ Komola Rocket (2018) → Rating: 7.3, Director: Noor Imran Mithu
# ✅ Nang Nak (1999) → Rating: 6.5, Director: Nonzee Nimibutr
# ✅ And Breathe Normally (2018) → Rating: 6.9, Director: Ísold Uggadóttir
# ❌ Not found: 'El Potro: Unstoppable' (2018) → Reason: Movie not found!
# ✅ Lionheart (2018) → Rating: 5.7, Director: Genevieve Nnaji
# ✅ See You in Time (2017) → Rating: 7.0, Director: N/A
# ⏭️  Skipping (rating & director already present): Déjà Vu
# ⏭️  Skipping (rating & director already present): Monty Python and the Holy Grail
# ⏭️  Skipping (rating & director already present): A Series of Unfortunate Events
# ⏭️  Skipping (rating & director already present): Back to the 90s
# 💾 Saved progress at row 4220 (every 10)
# ⏭️  Skipping (rating & director already present): COMEDIANS of the world
# ⏭️  Skipping (rating & director already present): Merku Thodarchi Malai
# ✅ Moshe Kasher: Live in Oakland (2012) → Rating: 6.6, Director: Jay Chapman
# ⏭️  Skipping (rating & director already present): Pokémon the Movie: I Choose You!
# ⏭️  Skipping (rating & director already present): Puriyatha Puthir
# ⏭️  Skipping (rating & director already present): Taramani
# ✅ The Paper (2018) → Rating: nan, Director: Diane Perelsztejn
# ⏭️  Skipping (rating & director already present): Tidying Up with Marie Kondo
# ⏭️  Skipping (rating & director already present): Whitney Cummings: Money Shot
# ⏭️  Skipping (rating & director already present): Bill Hicks: One Night Stand
# 💾 Saved progress at row 4230 (every 10)
# ⏭️  Skipping (rating & director already present): Bill Hicks: Reflections
# ✅ Bill Hicks: Relentless (1992) → Rating: 8.6, Director: Chris Bould
# ⏭️  Skipping (rating & director already present): Bill Hicks: Revelations
# ✅ Bill Hicks: Sane Man (1989) → Rating: 8.4, Director: Kevin Booth, David Johndrow
# ⏭️  Skipping (rating & director already present): Gina Yashere: Laughing to America
# ✅ Gina Yashere: Skinny B*tch (2008) → Rating: 6.5, Director: Paul M. Green
# ⏭️  Skipping (rating & director already present): Mexicanos de Bronce
# ⏭️  Skipping (rating & director already present): Sam Kinison: Breaking the Rules
# ⏭️  Skipping (rating & director already present): Sam Kinison: Family Entertainment Hour
# ⏭️  Skipping (rating & director already present): Sam Kinison: Live in Vegas
# 💾 Saved progress at row 4240 (every 10)
# ⏭️  Skipping (rating & director already present): Sam Kinison: The Scream Continues
# ✅ Secrets in the Hot Spring (2018) → Rating: 6.1, Director: Kuan-Hui Lin
# ✅ Taylor Swift reputation Stadium Tour (2018) → Rating: 8.4, Director: Paul Dugdale
# ⏭️  Skipping (rating & director already present): The Seven Deadly Sins the Movie: Prisoners of the Sky
# ✅ Tim Allen: Men Are Pigs (1990) → Rating: 6.2, Director: Ellen Brown
# ⏭️  Skipping (rating & director already present): Tim Allen: ReWires America
# ⏭️  Skipping (rating & director already present): Tim Minchin And The Heritage Orchestra Live
# ✅ Tim Minchin: So F**king Rock (2008) → Rating: 8.1, Director: Matt Askem
# ⏭️  Skipping (rating & director already present): Todd Glass: Stand-Up Special
# ✅ Tom Papa Live in New York City (2011) → Rating: 7.2, Director: Rob Zombie
# 💾 Saved progress at row 4250 (every 10)
# ⏭️  Skipping (rating & director already present): Pioneers: First Women Filmmakers*
# ⏭️  Skipping (rating & director already present): In Family We Trust
# ⏭️  Skipping (rating & director already present): A Twelve Year Night
# ⏭️  Skipping (rating & director already present): Black Mirror: Bandersnatch
# ⏭️  Skipping (rating & director already present): Hashoter Hatov
# ✅ Life Ki Toh Lag Gayi (2012) → Rating: 5.2, Director: Rakesh Mehta
# ✅ Murder Mountain (2018) → Rating: 6.8, Director: N/A
# ⏭️  Skipping (rating & director already present): Selection Day
# ❌ Not found: 'The Birth Reborn 3' (2018) → Reason: Movie not found!
# ✅ When Angels Sleep (2018) → Rating: 5.5, Director: Gonzalo Bendala
# 💾 Saved progress at row 4260 (every 10)
# ❌ Not found: 'Stand Up and Away! with Brian Regan' (2018) → Reason: Movie not found!
# ✅ Way Back into Love (2011) → Rating: 6.6, Director: David Freydt
# ✅ Watership Down (2018) → Rating: 7.2, Director: Noam Murro
# ✅ Demon's Path (2018) → Rating: 3.2, Director: Aja Blue Garman
# ⏭️  Skipping (rating & director already present): People Just Do Nothing
# ❌ Not found: 'Single Ladies Senior' (2018) → Reason: Movie not found!
# ✅ 7 Days Out (2018) → Rating: 6.7, Director: David Freydt
# ✅ Bad Seeds (2018) → Rating: 7.3, Director: Kheiron
# ⏭️  Skipping (rating & director already present): Bird Box
# ⏭️  Skipping (rating & director already present): Jojo's World
# 💾 Saved progress at row 4270 (every 10)
# ⏭️  Skipping (rating & director already present): LAST HOPE
# ✅ Lion Pride (2017) → Rating: 7.5, Director: Dingding Ou
# ⏭️  Skipping (rating & director already present): Love @ Seventeen
# ⏭️  Skipping (rating & director already present): Perfume
# ⏭️  Skipping (rating & director already present): Sirius the Jaeger
# ⏭️  Skipping (rating & director already present): Struggle: The Life and Lost Art of Szukalski
# ⏭️  Skipping (rating & director already present): Wolf
# ⏭️  Skipping (rating & director already present): 23:59
# ❌ Not found: 'Aggretsuko: We Wish You a Metal Christmas' (2018) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Fate/stay night: Unlimited Blade Works
# 💾 Saved progress at row 4280 (every 10)
# ⏭️  Skipping (rating & director already present): Imperfect
# ⏭️  Skipping (rating & director already present): Lang Tong
# ⏭️  Skipping (rating & director already present): Miss J Contemplates Her Choice
# ⏭️  Skipping (rating & director already present): Ascharyachakit!
# ✅ Ellen DeGeneres: Relatable (2018) → Rating: 6.5, Director: Joel Gallen, Tig Notaro
# ⏭️  Skipping (rating & director already present): Lilli
# ❌ Not found: 'Prince of Peoria: A Christmas Moose Miracle' (2018) → Reason: Movie not found!
# ⏭️  Skipping (rating & director already present): Andhadhun
# ⏭️  Skipping (rating & director already present): Ashes of Love
# ✅ Dragons: Dawn of the Dragon Racers (2014) → Rating: 7.0, Director: Elaine Bogan, John Sanford
# 💾 Saved progress at row 4290 (every 10)
# ❌ Not found: 'DreamWorks Holiday Classics' (2011) → Reason: Request limit reached!
#
# 🛑 OMDb daily request limit reached! Stopping.
# ✅ Final progress saved to netflix_titles(modified_Final).csv
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\Manchey\anaconda3\envs\aaaa\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
